# %%
from qiskit.transpiler import CouplingMap, PassManager

# %%
def _ring_coupling_map(num_qubits: int) -> CouplingMap:
    edges = [(idx, (idx + 1) % num_qubits) for idx in range(num_qubits)]
    edges += [((idx + 1) % num_qubits, idx) for idx in range(num_qubits)]
    return CouplingMap(edges)

# %%
print(_ring_coupling_map(5))
# Out:
# [[0, 1], [1, 2], [2, 3], [3, 4], [4, 0], [1, 0], [2, 1], [3, 2], [4, 3], [0, 4]]

# %%
pip install qiskit
# Out:
# Collecting qiskit
#   Using cached qiskit-2.4.1-cp310-abi3-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Using cached rustworkx-0.17.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.21 in /opt/anaconda3/envs/circuits/lib/python3.11/site-packages (from qiskit) (2.4.6)
# Collecting scipy>=1.5 (from qiskit)
#   Using cached scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting dill>=0.3 (from qiskit)
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Using cached stevedore-5.8.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/circuits/lib/python3.11/site-packages (from qiskit) (4.15.0)
# Using cached qiskit-2.4.1-cp310-abi3-macosx_11_0_arm64.whl (8.3 MB)
# Using cached dill-0.4.1-py3-none-any.whl (120 kB)
# Using cached rustworkx-0.17.1-cp39-abi3-macosx_11_0_arm64.whl (2.0 MB)
# Using cached scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl (20.3 MB)
# Using cached stevedore-5.8.0-py3-none-any.whl (54 kB)
# Installing collected packages: stevedore, scipy, rustworkx, dill, qiskit
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [qiskit]2m4/5 [qiskit]
# Successfully installed dill-0.4.1 qiskit-2.4.1 rustworkx-0.17.1 scipy-1.17.1 stevedore-5.8.0
# Note: you may need to restart the kernel to use updated packages.
