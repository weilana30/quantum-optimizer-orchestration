# %%
import pandas as pd
import sys
from qiskit import QuantumCircuit
import pylatexenc

# %%
circuit_path = "/Users/andrewweiland/UCCS_REU/quantum-optimizer-orchestration/benchmarks/ai_transpile/qasm/efficient_su2_8.qasm"

circuit = QuantumCircuit.from_qasm_file(circuit_path)
print(circuit)
print("Depth:", circuit.depth())
print("2Q gates:", circuit.num_nonlocal_gates())
print("Total gates:", circuit.size())
# Out:
#      ┌─────────┐┌─────────┐                                                  »
# q_0: ┤ Ry(0.1) ├┤ Rz(4.7) ├──■────■─────────■─────────■──────────────■───────»
#      ├─────────┤├─────────┤┌─┴─┐  │         │         │              │       »
# q_1: ┤ Ry(1.2) ├┤ Rz(4.8) ├┤ X ├──┼────■────┼────■────┼─────────■────┼───────»
#      ├─────────┤├─────────┤└───┘┌─┴─┐┌─┴─┐  │    │    │         │    │       »
# q_2: ┤ Ry(2.3) ├┤ Rz(0.2) ├─────┤ X ├┤ X ├──┼────┼────┼────■────┼────┼────■──»
#      ├─────────┤├─────────┤     └───┘└───┘┌─┴─┐┌─┴─┐  │  ┌─┴─┐  │    │    │  »
# q_3: ┤ Ry(3.4) ├┤ Rz(0.3) ├───────────────┤ X ├┤ X ├──┼──┤ X ├──┼────┼────┼──»
#      ├─────────┤├─────────┤               └───┘└───┘┌─┴─┐└───┘┌─┴─┐  │  ┌─┴─┐»
# q_4: ┤ Ry(4.3) ├┤ Rz(0.4) ├─────────────────────────┤ X ├─────┤ X ├──┼──┤ X ├»
#      ├─────────┤├─────────┤                         └───┘     └───┘┌─┴─┐└───┘»
# q_5: ┤ Ry(4.4) ├┤ Rz(0.5) ├────────────────────────────────────────┤ X ├─────»
#      ├─────────┤├─────────┤                                        └───┘     »
# q_6: ┤ Ry(4.5) ├┤ Rz(0.6) ├──────────────────────────────────────────────────»
#      ├─────────┤├─────────┤                                                  »
# q_7: ┤ Ry(4.6) ├┤ Rz(0.7) ├──────────────────────────────────────────────────»
#      └─────────┘└─────────┘                                                  »
# «                                   ┌─────────┐┌─────────┐                »
# «q_0: ───────■───────────────────■──┤ Ry(0.8) ├┤ Rz(1.7) ├────────────────»
# «            │                   │  └─────────┘└─────────┘     ┌─────────┐»
# «q_1: ──■────┼──────────────■────┼──────────────────────────■──┤ Ry(0.9) ├»
# «       │    │              │    │                          │  └─────────┘»
# «q_2: ──┼────┼─────────■────┼────┼──────────────────■───────┼─────────────»
# «       │    │         │    │    │                  │       │             »
# «q_3: ──┼────┼────■────┼────┼────┼───────■──────────┼───────┼─────────────»
# «       │    │  ┌─┴─┐  │    │    │       │          │       │             »
# «q_4: ──┼────┼──┤ X ├──┼────┼────┼───────┼──────────┼───────┼───────■─────»
# «     ┌─┴─┐  │  └───┘┌─┴─┐  │    │     ┌─┴─┐        │       │     ┌─┴─┐   »
# «q_5: ┤ X ├──┼───────┤ X ├──┼────┼─────┤ X ├────────┼───────┼─────┤ X ├───»
# «     └───┘┌─┴─┐     └───┘┌─┴─┐  │     └───┘      ┌─┴─┐     │     └───┘   »
# «q_6: ─────┤ X ├──────────┤ X ├──┼────────────────┤ X ├─────┼─────────────»
# «          └───┘          └───┘┌─┴─┐              └───┘   ┌─┴─┐           »
# «q_7: ─────────────────────────┤ X ├──────────────────────┤ X ├───────────»
# «                              └───┘                      └───┘           »
# «                                                                        »
# «q_0: ─────────────■───────────────────────────■───────────────────■─────»
# «     ┌─────────┐┌─┴─┐                         │                   │     »
# «q_1: ┤ Rz(1.8) ├┤ X ├─────────────────────────┼─────────■─────────┼─────»
# «     └─────────┘└───┘┌───────┐┌─────────┐   ┌─┴─┐     ┌─┴─┐       │     »
# «q_2: ─────────────■──┤ Ry(1) ├┤ Rz(1.9) ├───┤ X ├─────┤ X ├───────┼─────»
# «                  │  └───────┘└─────────┘┌──┴───┴──┐┌─┴───┴─┐   ┌─┴─┐   »
# «q_3: ─────■───────┼────────────────■─────┤ Ry(1.1) ├┤ Rz(2) ├───┤ X ├───»
# «          │       │                │     └─────────┘└───────┘┌──┴───┴──┐»
# «q_4: ─────┼───────┼──────■─────────┼────────────────────■────┤ Ry(1.3) ├»
# «          │       │      │         │                    │    └─────────┘»
# «q_5: ─────┼───────┼──────┼─────────┼──────────■─────────┼─────────■─────»
# «        ┌─┴─┐     │    ┌─┴─┐       │        ┌─┴─┐       │         │     »
# «q_6: ───┤ X ├─────┼────┤ X ├───────┼────────┤ X ├───────┼─────────┼─────»
# «        └───┘   ┌─┴─┐  └───┘     ┌─┴─┐      └───┘     ┌─┴─┐     ┌─┴─┐   »
# «q_7: ───────────┤ X ├────────────┤ X ├────────────────┤ X ├─────┤ X ├───»
# «                └───┘            └───┘                └───┘     └───┘   »
# «                                                                              »
# «q_0: ────────────────■───────────────────────■──────────────■─────────────────»
# «                     │                       │              │                 »
# «q_1: ─────■──────────┼──────────────────■────┼─────────■────┼──────────────■──»
# «          │          │                  │    │         │    │              │  »
# «q_2: ─────┼──────────┼──────────■───────┼────┼────■────┼────┼─────────■────┼──»
# «        ┌─┴─┐        │        ┌─┴─┐     │    │    │    │    │         │    │  »
# «q_3: ───┤ X ├────────┼────────┤ X ├─────┼────┼────┼────┼────┼────■────┼────┼──»
# «     ┌──┴───┴──┐   ┌─┴─┐      └───┘   ┌─┴─┐  │  ┌─┴─┐  │    │  ┌─┴─┐  │    │  »
# «q_4: ┤ Rz(2.1) ├───┤ X ├──────────────┤ X ├──┼──┤ X ├──┼────┼──┤ X ├──┼────┼──»
# «     ├─────────┤┌──┴───┴──┐           └───┘┌─┴─┐└───┘┌─┴─┐  │  └───┘┌─┴─┐  │  »
# «q_5: ┤ Ry(1.4) ├┤ Rz(2.2) ├────────────────┤ X ├─────┤ X ├──┼───────┤ X ├──┼──»
# «     └─────────┘├─────────┤┌─────────┐     └───┘     └───┘┌─┴─┐     └───┘┌─┴─┐»
# «q_6: ─────■─────┤ Ry(1.5) ├┤ Rz(2.4) ├────────────────────┤ X ├──────────┤ X ├»
# «        ┌─┴─┐   ├─────────┤├─────────┤                    └───┘          └───┘»
# «q_7: ───┤ X ├───┤ Ry(1.6) ├┤ Rz(2.5) ├────────────────────────────────────────»
# «        └───┘   └─────────┘└─────────┘                                        »
# «          ┌─────────┐┌─────────┐                                           »
# «q_0: ──■──┤ Ry(2.6) ├┤ Rz(3.5) ├───────────────────────────────────────────»
# «       │  └─────────┘└─────────┘     ┌─────────┐┌─────────┐                »
# «q_1: ──┼──────────────────────────■──┤ Ry(2.7) ├┤ Rz(3.6) ├────────────────»
# «       │                          │  └─────────┘└─────────┘     ┌─────────┐»
# «q_2: ──┼──────────────────■───────┼──────────────────────────■──┤ Ry(2.8) ├»
# «       │                  │       │                          │  └─────────┘»
# «q_3: ──┼───────■──────────┼───────┼──────────────────■───────┼─────────────»
# «       │       │          │       │                  │       │             »
# «q_4: ──┼───────┼──────────┼───────┼───────■──────────┼───────┼───────■─────»
# «       │     ┌─┴─┐        │       │     ┌─┴─┐        │       │       │     »
# «q_5: ──┼─────┤ X ├────────┼───────┼─────┤ X ├────────┼───────┼───────┼─────»
# «       │     └───┘      ┌─┴─┐     │     └───┘      ┌─┴─┐     │     ┌─┴─┐   »
# «q_6: ──┼────────────────┤ X ├─────┼────────────────┤ X ├─────┼─────┤ X ├───»
# «     ┌─┴─┐              └───┘   ┌─┴─┐              └───┘   ┌─┴─┐   └───┘   »
# «q_7: ┤ X ├──────────────────────┤ X ├──────────────────────┤ X ├───────────»
# «     └───┘                      └───┘                      └───┘           »
# «                                                                     »
# «q_0: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «q_1: ────────────────────────────────────────────────────────────────»
# «     ┌─────────┐                                                     »
# «q_2: ┤ Rz(3.7) ├─────────────────────────────────────────────────────»
# «     └─────────┘┌─────────┐┌─────────┐                               »
# «q_3: ─────■─────┤ Ry(2.9) ├┤ Rz(3.8) ├───────────────────────────────»
# «          │     └─────────┘└─────────┘┌───────┐┌─────────┐           »
# «q_4: ─────┼─────────────────────■─────┤ Ry(3) ├┤ Rz(3.9) ├───────────»
# «          │                     │     └───────┘├─────────┤ ┌───────┐ »
# «q_5: ─────┼──────────■──────────┼─────────■────┤ Ry(3.1) ├─┤ Rz(4) ├─»
# «          │        ┌─┴─┐        │         │    └─────────┘┌┴───────┴┐»
# «q_6: ─────┼────────┤ X ├────────┼─────────┼─────────■─────┤ Ry(3.2) ├»
# «        ┌─┴─┐      └───┘      ┌─┴─┐     ┌─┴─┐     ┌─┴─┐   ├─────────┤»
# «q_7: ───┤ X ├─────────────────┤ X ├─────┤ X ├─────┤ X ├───┤ Ry(3.3) ├»
# «        └───┘                 └───┘     └───┘     └───┘   └─────────┘»
# «
# «q_0: ───────────
# «
# «q_1: ───────────
# «
# «q_2: ───────────
# «
# «q_3: ───────────
# «
# «q_4: ───────────
# «
# «q_5: ───────────
# «     ┌─────────┐
# «q_6: ┤ Rz(4.1) ├
# «     ├─────────┤
# «q_7: ┤ Rz(4.2) ├
# «     └─────────┘
# Depth: 27
# 2Q gates: 56
# Total gates: 104
